# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## Restructure the Participation Data

# %%
participations = pd.read_pickle('../../data/raw/participation_data')

# %%
len(participations)
# Out:
# 1474748

# %%
participations.describe()
# Out:
#         duration        index_     magnitude       project  repetitions
# count  1474748.0  1.474748e+06  1.474748e+06  1.261569e+06    1474748.0
# mean         0.0  7.373751e+05  1.746123e+01  1.369494e+03          1.0
# std          0.0  4.257236e+05  1.783508e+01  2.715116e+03          0.0
# min          0.0  1.000000e+00  0.000000e+00  4.000000e+00          1.0
# 25%          0.0  3.686878e+05  1.000000e+00  1.014000e+03          1.0
# 50%          0.0  7.373755e+05  1.000000e+00  1.014000e+03          1.0
# 75%          0.0  1.106062e+06  3.900000e+01  1.014000e+03          1.0
# max          0.0  1.474749e+06  4.000000e+01  2.065500e+04          1.0

# %%
participations.tail()
# Out:
#         authenticated  duration extra  index_  magnitude       origin  \
# 289042           True         0        537244         40  Unspecified
# 289043           True         0        537245         40  Unspecified
# 289044           True         0        537246         40  Unspecified
# 289045           True         0        537247         40  Unspecified
# 289046           True         0        537248         40  Unspecified
#
#                                  profile profile_origin  \
# 289042  299a04f44bdef72485d628557c056d8a
# 289043  299a04f44bdef72485d628557c056d8a
# 289044  299a04f44bdef72485d628557c056d8a
# 289045  299a04f44bdef72485d628557c056d8a
# 289046  299a04f44bdef72485d628557c056d8a
#
#                                          profile_referrer  \
# 289042  https://stallcatchers.com/virtualMicroscope?au...
# 289043  https://stallcatchers.com/virtualMicroscope?au...
# 289044  https://stallcatchers.com/virtualMicroscope?au...
# ...

# %% [markdown]
# ## Restructure the Project Data

# %%
projects = pd.read_pickle('../Data/project_data')

# %%
len(projects)
# Out:
# 1781

# %%
projects.head()
# Out:
#   UN_regions country                                        description error  \
# 0         []          Foldit is a revolutionary new computer game en...   NaN
# 1         []          Firefly Watch combines an annual summer evenin...   NaN
# 2         []          Galaxy Zoo needs your help to classify galaxie...   NaN
# 3         []    None  Pay attention to the plants and animals in you...   NaN
# 4         []          A recent issue of Make magazine (http://makezi...   NaN
#
#                                    guid      origin  \
# 0  5f80760d-8398-5091-b3c6-f34c39216e88  scistarter
# 1  c9664e0c-819a-5a42-b4bb-5f25d83a486d  scistarter
# 2  11f65e99-b463-5e01-ac11-ae59c021dfe7  scistarter
# 3                   wilsoncenter:27-107  scistarter
# 4  ae91e967-6eec-5aef-ab3a-7d86ceff737a  scistarter
#
#                                              regions  \
# 0                                                 []
# 1  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# ...
