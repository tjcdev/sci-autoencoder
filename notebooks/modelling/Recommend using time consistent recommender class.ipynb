# %% [markdown]
# # Recommend projects to users using the time consistent recommend class

# %%
from keras.models import load_model
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np
np.random.seed(0)
from time import gmtime, strftime
from keras.models import Model
from scipy.sparse import vstack

import os
import sys
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.models.cdea.evaluate import evaluate
from src.models.cdea.timerecommender import Recommender
import src.models.cdea.load_data as load_data

import math

from sklearn.metrics import precision_recall_fscore_support

# %%
users_projects_list = pd.read_pickle('../../data/processed/profile_projects_time_consistent')
projects = pd.read_pickle('../../data/raw/project_data')
users_projects_matrix =  pd.read_pickle('../../data/processed/active_profile_projects')
similarity_matrix = pd.read_pickle('../../data/processed/similarity_matrix')
# Normalise the similarity
similarity_matrix = (similarity_matrix + 1) / 2

# %%
num_uniques = lambda x: len(set([i for i in x if not math.isnan(i)]))
users_projects_list['num_projects'] = users_projects_list['projects'].apply(num_uniques)

# %%
users_projects_list
# Out:
#                                 profile  \
# 0      000073c3675ea9a1d0fe0ee3ca57e2bf
# 1      0002b85e757486c6d80ed6f73f465eaa
# 2      0003a41bbdb3371df4c1829913f17537
# 3      000436aaa487e461e6e16e02ab3e89eb
# 4      000476d8680db78d75b3b9edefc4a6d2
# 5      0004853e76f038acb207adaa98cc4afb
# 6      00060488471cb4e5b085e50291d4a3e0
# 7      00060e78dfb9091883494f288a1e20e4
# 8      0006e4b3c3848d18512fdf38df7b0a60
# 9      0007997ece92bc1a4ea4e570093da014
# 10     0008be86a1b78ca8b274eeadc7c172f2
# 11     000944c8fb77623b1c1c6aab1968b061
# 12     000a368e2c461587a9a5ef864b3356f8
# 13     000c17eb36af693233f51ef5a9a33cfc
# 14     000c5145b1c0fa2626aeb6ce02ba4ba1
# 15     000eebee97d3ba7e9213d1701d7c0775
# 16     001141ccff5d7eba6451e3508a0b490b
# 17     00124d191da6f48880083f7afecd4f3e
# 18     0013846c2ec8e3352283b8b4076a9216
# 19     0013a517832195033cea8c4371cc36bf
# 20     0013d9cc39650e6771cbaf069c286cc6
# 21     001539ecec20d5ac1da9bb5ac896f033
# 22     0015a850ad8f7a2b688a927f6486ece8
# 23     0015df64281536dd1e1f033ba1d39a06
# 24     001794a35f4e80ade95e8078ccd6eb41
# 25     00189f9a056b497951992f39db071a34
# 26     0019bb571530c82982bde7af27a83430
# 27     001b02d5178d34da72153bca05c65dc1
# 28     001b154757ef3a77fae3c02ab9148107
# 29     001b15c7ff3aea81011294b14f0a5732
# ...                                 ...
# 76352  ffe3b20ada59772658346edfc4fbbaa1
# 76353  ffe3c15a7f341eaa5844a157ccb4764e
# 76354  ffe3ce17146ede5813e52e796a7094c0
# 76355  ffe53df5ffbffd4afdeaefed54c7e91c
# 76356  ffe593b384a5f663b2c23ffa3698e3b0
# 76357  ffe609b7cc1975b0535ec1198408f5dc
# 76358  ffe645b404146b8817000e15cc461c10
# 76359  ffe7209b4ef98c2e5522015d28f52205
# 76360  ffe8c1c1ea37b377d9b1e3890881d72a
# 76361  ffe8e739de06de73222d1ea974681f76
# 76362  ffe91701b4f00f121328c0587b92b5e2
# 76363  ffe982eee539f81a6c47eeeb4149bd05
# 76364  ffebdb53807fa80a57c3ff648336e321
# 76365  ffec069f8c091a355308fa5273cff4ea
# 76366  ffec8cb90395feaab9d1ad8a71ab032c
# 76367  ffedec8c17ec6f24dfa94dfc0faf68f1
# 76368  ffee921319221a4453992c401ff65aab
# 76369  fff078c5cc9e4fa55dbdc737a36ef536
# 76370  fff0f17ef602ebade0e9b1aeee807125
# 76371  fff207eb43c06973fc7b6b75b9b57856
# 76372  fff533919de6cb46896be4fc079cc6a2
# 76373  fff5a2b4907aac15f8dead80fec10f8c
# 76374  fff6b90e734af6d153f5d1d58edce1fe
# 76375  fff7f768dac7aaa9e5d2b7ed60569c9c
# 76376  fff9d5d756cb28d954fc1e7252585b55
# 76377  fffa095bfa6c965df8fb14d4aa513397
# 76378  fffa7925d905995c73168e4f710a852b
# 76379  fffb804f713fdf0733cd3741fc98a335
# 76380  fffe67794536df60188d62d0b8b5b0ee
# 76381  ffffef31f9eb8792a15ecd5d67cdfd79
#
#                                                 projects  num_projects
# 0                                         [413.0, 413.0]             1
# 1                                              [16864.0]             1
# 2                                              [19794.0]             1
# 3                                                [659.0]             1
# 4                                               [1510.0]             1
# 5                                                [846.0]             1
# 6                                                [720.0]             1
# 7                                                 [25.0]             1
# 8                                                 [25.0]             1
# 9                                                 [25.0]             1
# 10                           [17491.0, 17491.0, 17491.0]             1
# 11                                               [169.0]             1
# 12                                       [nan, nan, nan]             0
# 13                               [16830.0, 16830.0, nan]             1
# 14                                                [25.0]             1
# 15                                                [25.0]             1
# 16                                                [25.0]             1
# 17     [1014.0, 1014.0, 1014.0, 1014.0, 1014.0, 1014....             1
# 18                                                [25.0]             1
# 19                                               [169.0]             1
# 20     [25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25....             1
# 21                                               [996.0]             1
# 22                                               [169.0]             1
# 23                                        [566.0, 566.0]             1
# 24                                                [25.0]             1
# 25                                                [25.0]             1
# 26                                                [25.0]             1
# 27                                                [25.0]             1
# 28                                                [25.0]             1
# 29                                            [nan, nan]             0
# ...                                                  ...           ...
# 76352                                             [25.0]             1
# 76353  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...            18
# 76354                                         [nan, nan]             0
# 76355                      [373.0, 373.0, nan, nan, nan]             1
# 76356                                             [25.0]             1
# 76357  [nan, nan, nan, nan, nan, 995.0, 995.0, nan, 4...             4
# 76358                                             [25.0]             1
# 76359                                             [25.0]             1
# 76360                                     [169.0, 169.0]             1
# 76361                                             [25.0]             1
# 76362                                             [25.0]             1
# 76363                     [nan, nan, nan, nan, nan, nan]             0
# 76364                           [25.0, 25.0, 25.0, 25.0]             1
# 76365                                            [169.0]             1
# 76366                                            [972.0]             1
# 76367                                     [169.0, 169.0]             1
# 76368                                   [1393.0, 1393.0]             1
# 76369                                             [25.0]             1
# 76370                                       [25.0, 25.0]             1
# 76371                                             [25.0]             1
# 76372                                           [1068.0]             1
# 76373                              [446.0, 446.0, 446.0]             1
# 76374           [nan, nan, nan, nan, nan, nan, nan, nan]             0
# 76375                                             [25.0]             1
# 76376                                             [25.0]             1
# 76377                                             [25.0]             1
# 76378                                            [169.0]             1
# 76379                       [169.0, 169.0, 169.0, 169.0]             1
# 76380  [nan, nan, nan, nan, nan, nan, 17051.0, 17051....             1
# 76381                                            [636.0]             1
#
# [76382 rows x 3 columns]

# %%
# Setup our recommender
rec = Recommender(projects, users_projects_matrix)

# %%
# Pick out the user we want
user_projects_list = users_projects_list[users_projects_list['num_projects'] > 7].iloc[1000]

# %%
# Get the top projects
after_cutoff, similar_items = rec.top_projects(user_projects_list, similarity_matrix)

# %%
print(after_cutoff)
similar_items
# Out:
# [54.0, 113.0, 1014.0]
#       similarity_score  project_id
# 1114          0.510002     15386.0
# 1165          0.509387     17002.0
# 1085          0.508914     11457.0
# 1350          0.508463     18304.0
# 1669          0.508274     20136.0

# %%
# Generate our y_true and y_pred
y_true, y_pred = rec.predictions(after_cutoff, similar_items)

# %%
# Evaluate our model
precision, recall, refined_precision = evaluate(y_true, y_pred, similar_items, similarity_matrix)
# Out:
# 5
# 1
# (3, 5)

# %%
# Get precision and recall
precision, recall, fscore, support = precision_recall_fscore_support(y_true, y_pred, average='binary', pos_label=1)

# %%
# Get the similarity matrix entries for the most similar items to our 
pred_sim_matrix = similarity_matrix[similar_items.index]

# %%
pred_sim_matrix
# Out:
#            1114      1165      1085      1350      1669
# 4      0.864343  0.854669  0.958687  0.910340  0.954326
# 5      0.842162  0.866112  0.968375  0.920734  0.966418
# 6      0.843234  0.863065  0.966517  0.918774  0.964491
# 7      0.158914  0.136758  0.033827  0.080069  0.035619
# 8      0.843391  0.874446  0.972399  0.919870  0.970963
# 19     0.831739  0.893590  0.981979  0.930778  0.981150
# 20     0.843228  0.863159  0.966604  0.918813  0.964591
# 22     0.840871  0.860136  0.964656  0.919179  0.964379
# 23     0.843185  0.863168  0.966622  0.918909  0.964613
# 24     0.156429  0.135515  0.032176  0.079809  0.034226
# 25     0.148066  0.178014  0.066173  0.122328  0.069608
# 26     0.860151  0.857294  0.959840  0.914867  0.957114
# 27     0.143958  0.139372  0.035831  0.090185  0.038715
# 28     0.157054  0.135759  0.032856  0.079910  0.034787
# 29     0.301865  0.257155  0.277423  0.259103  0.280528
# 30     0.157584  0.132979  0.029390  0.080318  0.034388
# 31     0.148016  0.138461  0.041842  0.091639  0.044153
# 32     0.157241  0.133944  0.032408  0.080506  0.033573
# 33     0.159981  0.136776  0.032700  0.077978  0.034507
# 34     0.151356  0.130106  0.032183  0.074259  0.030831
# 35     0.174884  0.077653  0.018473  0.060126  0.036093
# 36     0.836802  0.865552  0.971932  0.919272  0.966808
# 37     0.157007  0.136235  0.032832  0.080687  0.034960
# 38     0.164606  0.159541  0.050348  0.104474  0.051090
# 39     0.845458  0.886001  0.975995  0.929092  0.972882
# 40     0.779517  0.551900  0.547382  0.552967  0.518278
# 41     0.156854  0.136175  0.032779  0.080349  0.034896
# 42     0.840539  0.872210  0.970741  0.920191  0.966923
# 43     0.839659  0.851766  0.958646  0.919001  0.962210
# 44     0.843823  0.862627  0.966125  0.918708  0.964207
# ...         ...       ...       ...       ...       ...
# 286    0.154816  0.145419  0.046471  0.107717  0.045213
# 287    0.843020  0.866602  0.969497  0.919982  0.966058
# 288    0.187956  0.179240  0.069649  0.094021  0.055458
# 289    0.851135  0.865562  0.966094  0.915705  0.963260
# 290    0.236262  0.148281  0.050647  0.066245  0.067566
# 291    0.195509  0.167872  0.041887  0.080219  0.033913
# 292    0.830656  0.805886  0.918548  0.876107  0.923299
# 293    0.165574  0.121667  0.036028  0.078591  0.028722
# 294    0.839826  0.867191  0.968870  0.918417  0.964844
# 295    0.296391  0.315674  0.300448  0.356556  0.238313
# 296    0.842099  0.864847  0.967145  0.918751  0.965034
# 297    0.821246  0.891266  0.968627  0.933310  0.975642
# 298    0.830716  0.785048  0.888977  0.853651  0.885085
# 299    0.846318  0.855838  0.961763  0.913873  0.959238
# 300    0.814739  0.884734  0.980091  0.924447  0.982884
# 301    0.845520  0.862604  0.965782  0.918119  0.963467
# 302    0.187671  0.117979  0.038474  0.064619  0.044953
# 303    0.839091  0.863969  0.957539  0.897542  0.949577
# 304    0.149500  0.138176  0.036041  0.083734  0.038390
# 305    0.123368  0.145461  0.036736  0.083368  0.042702
# 307    0.841728  0.864664  0.967622  0.920790  0.965516
# 308    0.154335  0.141049  0.036656  0.087126  0.038676
# 309    0.159946  0.155961  0.072435  0.135698  0.080969
# 310    0.147193  0.151901  0.041699  0.094164  0.050985
# 311    0.844541  0.857976  0.963908  0.915114  0.961805
# 312    0.844544  0.869802  0.973282  0.917779  0.965134
# 18862  0.802869  0.707634  0.824055  0.723518  0.796409
# 18999  0.167960  0.130882  0.032406  0.069086  0.033052
# 19535  0.841636  0.866383  0.967927  0.921036  0.965624
# 19847  0.847737  0.790907  0.901320  0.827992  0.910880
#
# [1781 rows x 5 columns]

# %%
# Get the indices of all the projects that were actually participated with after cut_off time
true_idx = np.nonzero(y_true)

# %%
true_idx
# Out:
# (array([ 38,  58, 664]),)

# %%
# This should now mean we have a 2D matrix which has 
# len(similar_items) columns 
# len(true_idx) rows
masked_pred_sim_matrix = pred_sim_matrix.iloc[true_idx]

# %%
masked_pred_sim_matrix
# Out:
#           1114      1165      1085      1350      1669
# 54    0.214877  0.099774  0.020666  0.064045  0.021312
# 113   0.843539  0.858113  0.965070  0.915394  0.960541
# 1014  0.159744  0.137553  0.031976  0.079158  0.032628

# %%
np.mean(masked_pred_sim_matrix.max(axis=0))
# Out:
# 0.90853155

# %%
print(precision)
print(recall)
print(refined_precision)
# Out:
# 0.0
# 0.0
# 0.9085315465927124
