# %%
import pandas as pd
import json
import numpy as np

# %%
# Read results
results = pd.read_json('../../data/experiment-results/cf-autoencoder/cf-item-1.json', lines=True)

# %%
results
# Out:
#      epoch  precision    recall  refined_precision
# 0        0          1  0.333333           1.000000
# 1        1          1  1.000000           1.028653
# 2        2          1  1.000000           2.000000
# 3        4          0  0.000000           0.000000
# 4        5          0  0.000000           0.000000
# 5        7          1  0.333333           1.085140
# 6        8          1  0.333333           1.036811
# 7       10          1  1.000000           1.000000
# 8       11          1  0.250000           1.099897
# 9       12          0  0.000000           0.000000
# 10      13          1  0.500000           1.194698
# 11      15          1  0.500000           1.081541
# 12      18          1  0.083333           1.071885
# 13      19          0  0.000000           0.000000
# 14      20          1  1.000000           1.000000
# 15      21          0  0.000000           0.000000
# 16      23          0  0.000000           0.000000
# ...

# %%
np.mean(results['precision'])
# Out:
# 0.6312056737588653

# %%
np.mean(results['recall'])
# Out:
# 0.339062816616008

# %%
np.mean(results['refined_precision'])
# Out:
# 0.7011606836012135
