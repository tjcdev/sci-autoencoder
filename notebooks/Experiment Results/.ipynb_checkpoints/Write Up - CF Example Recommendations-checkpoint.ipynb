# %%
import pandas as pd
import json
import numpy as np

# %%
# Read results
autoencoder_name = 'train_autoencoder_1024_deep3_new_users_projects_0.8_10'
results = pd.read_json('../../data/experiment-results/cf-autoencoder/%s.json' % (autoencoder_name), lines=True)

results = results.T
results['json'] = results[0]

newDataframe = pd.DataFrame(columns=['user_index', 'precision', 'recall', 'y_pred', 'y_true', 'len_yPred', 'len_yTrue', 'avg_precision', 'rmse'])
newDataframe['y_pred'] = newDataframe['y_pred'].astype(object)
newDataframe['y_true'] = newDataframe['y_true'].astype(object)

for index, row in results.iterrows():
    newSeries = pd.Series(index=['user_index', 'precision', 'recall', 'y_pred', 'y_true', 'len_yPred', 'len_yTrue'])
    newSeries['y_pred'] = newSeries['y_pred'].astype(object)
    newSeries['y_true'] = newSeries['y_true'].astype(object)

    newSeries['user_index'] = row['json']['user_index']
    newSeries['precision'] = row['json']['precision']
    newSeries['recall'] = row['json']['recall']

    things1 = np.array(row['json']['y_pred']).astype('str')
    things2 = np.array(row['json']['y_true']).astype('str')
    y_pred_string = '[' + ', '.join(things1) + ']'
    y_true_string = '[' + ', '.join(things2) + ']'
    
    newSeries['y_pred'] = y_pred_string
    newSeries['y_true'] = y_true_string
    
    newSeries['len_yPred'] = len(row['json']['y_pred'])
    newSeries['len_yTrue'] = len(row['json']['y_true'])
    
    newSeries['rmse'] = row['json']['rmse']
    newSeries['avg_precision'] = row['json']['avg_precision']
    
    newDataframe.loc[index] = newSeries
    
newDataframe.describe()
# Out:
#        user_index  precision  recall  avg_precision        rmse
# count  344.000000      344.0   344.0     344.000000  344.000000
# mean   171.500000        0.0     0.0       0.000152    0.005795
# std     99.448479        0.0     0.0       0.000323    0.010888
# min      0.000000        0.0     0.0       0.000000    0.000000
# 25%     85.750000        0.0     0.0       0.000000    0.000000
# 50%    171.500000        0.0     0.0       0.000000    0.000000
# 75%    257.250000        0.0     0.0       0.000000    0.000000
# max    343.000000        0.0     0.0       0.002807    0.052985

# %%
all_preds = np.array([])
for i in range(0, newDataframe.shape[1]):
    preds = np.asarray(newDataframe.iloc[i]['y_pred'][1:-1].split(', '), dtype=int)
    all_preds = np.append(all_preds, preds)
    
len(set(all_preds))
# Out:
# 10

# %%
set(all_preds)
# Out:
# {585.0, 586.0, 587.0, 588.0, 589.0, 590.0, 591.0, 592.0, 596.0, 1780.0}

# %%
newDataframe[newDataframe['y_true'] != '[]']
# Out:
#      user_index  precision  recall  \
# 0           0.0        0.0     0.0
# 3           3.0        0.0     0.0
# 5           5.0        0.0     0.0
# 14         14.0        0.0     0.0
# 28         28.0        0.0     0.0
# 30         30.0        0.0     0.0
# 33         33.0        0.0     0.0
# 34         34.0        0.0     0.0
# 35         35.0        0.0     0.0
# 39         39.0        0.0     0.0
# 40         40.0        0.0     0.0
# 43         43.0        0.0     0.0
# 48         48.0        0.0     0.0
# 50         50.0        0.0     0.0
# 51         51.0        0.0     0.0
# 54         54.0        0.0     0.0
# 58         58.0        0.0     0.0
# 69         69.0        0.0     0.0
# 74         74.0        0.0     0.0
# 75         75.0        0.0     0.0
# 78         78.0        0.0     0.0
# 81         81.0        0.0     0.0
# 83         83.0        0.0     0.0
# 86         86.0        0.0     0.0
# 89         89.0        0.0     0.0
# 91         91.0        0.0     0.0
# 99         99.0        0.0     0.0
# 109       109.0        0.0     0.0
# 110       110.0        0.0     0.0
# 111       111.0        0.0     0.0
# ..          ...        ...     ...
# 210       210.0        0.0     0.0
# 213       213.0        0.0     0.0
# 223       223.0        0.0     0.0
# 228       228.0        0.0     0.0
# 238       238.0        0.0     0.0
# 243       243.0        0.0     0.0
# 245       245.0        0.0     0.0
# 250       250.0        0.0     0.0
# 254       254.0        0.0     0.0
# 259       259.0        0.0     0.0
# 261       261.0        0.0     0.0
# 265       265.0        0.0     0.0
# 268       268.0        0.0     0.0
# 271       271.0        0.0     0.0
# 280       280.0        0.0     0.0
# 284       284.0        0.0     0.0
# 286       286.0        0.0     0.0
# 296       296.0        0.0     0.0
# 298       298.0        0.0     0.0
# 299       299.0        0.0     0.0
# 305       305.0        0.0     0.0
# 306       306.0        0.0     0.0
# 308       308.0        0.0     0.0
# 311       311.0        0.0     0.0
# 315       315.0        0.0     0.0
# 322       322.0        0.0     0.0
# 324       324.0        0.0     0.0
# 326       326.0        0.0     0.0
# 335       335.0        0.0     0.0
# 337       337.0        0.0     0.0
#
#                                                 y_pred                 y_true  \
# 0    [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [295]
# 3    [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 5    [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 14   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [700]
# 28   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 30   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 33   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 34   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [57]
# 35   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 39   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 40   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [60]
# 43   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 48   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [57]
# 50   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 51   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 54   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 58   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [59]
# 69   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 74   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [76]
# 75   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [60]
# 78   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [47]
# 81   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...  [44, 52, 60, 63, 700]
# 83   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 86   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 89   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 91   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 99   [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 109  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...               [44, 76]
# 110  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 111  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# ..                                                 ...                    ...
# 210  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 213  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 223  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 228  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 238  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 243  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [47]
# 245  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [700]
# 250  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 254  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 259  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 261  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [57]
# 265  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                  [138]
# 268  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [76]
# 271  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 280  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [47]
# 284  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...               [44, 47]
# 286  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [60]
# 296  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [47]
# 298  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 299  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 305  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [60]
# 306  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...               [52, 63]
# 308  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 311  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 315  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [44]
# 322  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [57]
# 324  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [42]
# 326  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...       [42, 44, 47, 52]
# 335  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [76]
# 337  [585, 586, 587, 588, 589, 590, 591, 592, 596, ...                   [57]
#
#     len_yPred len_yTrue  avg_precision      rmse
# 0          10         1       0.000561  0.023696
# 3          10         1       0.000561  0.023696
# 5          10         1       0.000561  0.023696
# 14         10         1       0.000561  0.023696
# 28         10         1       0.000561  0.023696
# 30         10         1       0.000561  0.023696
# 33         10         1       0.000561  0.023696
# 34         10         1       0.000561  0.023696
# 35         10         1       0.000561  0.023696
# 39         10         1       0.000561  0.023696
# 40         10         1       0.000561  0.023696
# 43         10         1       0.000561  0.023696
# 48         10         1       0.000561  0.023696
# 50         10         1       0.000561  0.023696
# 51         10         1       0.000561  0.023696
# 54         10         1       0.000561  0.023696
# 58         10         1       0.000561  0.023696
# 69         10         1       0.000561  0.023696
# 74         10         1       0.000561  0.023696
# 75         10         1       0.000561  0.023696
# 78         10         1       0.000561  0.023696
# 81         10         5       0.002807  0.052985
# 83         10         1       0.000561  0.023696
# 86         10         1       0.000561  0.023696
# 89         10         1       0.000561  0.023696
# 91         10         1       0.000561  0.023696
# 99         10         1       0.000561  0.023696
# 109        10         2       0.001123  0.033511
# 110        10         1       0.000561  0.023696
# 111        10         1       0.000561  0.023696
# ..        ...       ...            ...       ...
# 210        10         1       0.000561  0.023696
# 213        10         1       0.000561  0.023696
# 223        10         1       0.000561  0.023696
# 228        10         1       0.000561  0.023696
# 238        10         1       0.000561  0.023696
# 243        10         1       0.000561  0.023696
# 245        10         1       0.000561  0.023696
# 250        10         1       0.000561  0.023696
# 254        10         1       0.000561  0.023696
# 259        10         1       0.000561  0.023696
# 261        10         1       0.000561  0.023696
# 265        10         1       0.000561  0.023696
# 268        10         1       0.000561  0.023696
# 271        10         1       0.000561  0.023696
# 280        10         1       0.000561  0.023696
# 284        10         2       0.001123  0.033511
# 286        10         1       0.000561  0.023696
# 296        10         1       0.000561  0.023696
# 298        10         1       0.000561  0.023696
# 299        10         1       0.000561  0.023696
# 305        10         1       0.000561  0.023696
# 306        10         2       0.001123  0.033511
# 308        10         1       0.000561  0.023696
# 311        10         1       0.000561  0.023696
# 315        10         1       0.000561  0.023696
# 322        10         1       0.000561  0.023696
# 324        10         1       0.000561  0.023696
# 326        10         4       0.002246  0.047391
# 335        10         1       0.000561  0.023696
# 337        10         1       0.000561  0.023696
#
# [79 rows x 9 columns]

# %%
# Load projects
project_ids = pd.read_pickle('../../data/processed/cf_projects.pkl')
projects = pd.read_pickle('../../data/processed/project_data')

# %%
# Projects that were done
projects[projects['project_id'].isin(project_ids.iloc[[44, 52, 60, 63, 700]].values.flatten())]
# Out:
#      UN_regions country                                        description  \
# 65           []    None  Students’ Cloud Observations On-Line (S’COOL) ...
# 74           []          Herbaria@home is a ground-breaking new approac...
# 85           []          How much snow is on the ground where you are? ...
# 92           []          Volunteers are provided with equipment and tra...
# 1125         []    None  Noise and sounds in different forms are everyw...
#
#      error                                  guid      origin  \
# 65     NaN  b614446d-6707-5ecb-9f7c-937bde9590f6  scistarter
# 74     NaN  06235f72-f9d2-59f3-89fc-74783bf5efe9  scistarter
# 85     NaN  9fece8c0-af64-54ff-9aa8-0aa9b598eec6  scistarter
# 92     NaN  dfbcd555-5dce-5e44-827f-95b2d6806f23  scistarter
# 1125   NaN  506785b9-ab32-5eec-835c-45de6c0c7f1b  scistarter
#
#                                                 regions  \
# 65                                                   []
# 74                                                   []
# 85    [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 92    [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 1125  [{'geometry': {'type': 'MultiPolygon', 'coordi...
#
#                                                    tags  \
# 65    [climate, cloud, comparison, nasa, observation...
# 74                                                   []
# 85    [girl scouts, internal_girl_scouts, snow, twit...
# 92    [algae, blue green, blue green algae, boat, ch...
# 1125                     [city, noise pollution, sound]
#
#                                                title  \
# 65    Students’ Cloud Observations On-Line  (S’COOL)
# 74                                    Herbarium@home
# 85                                       Snow Tweets
# 92               Lakes of Missouri Volunteer Program
# 1125                               Sound Around Town
#
#                                                  topics  \
# 65    [Education, Nature & Outdoors, Climate & Weather]
# 74                                            [Animals]
# 85    [Geology & Earth Science, Computers & Technolo...
# 92    [Education, Chemistry, Nature & Outdoors, Ecol...
# 1125  [Science Policy, Nature & Outdoors, Social Sci...
#
#                                                     url  project_id
# 65    https://scistarter.com/project/121-Students-Cl...         121
# 74    https://scistarter.com/project/144-Herbariumho...         144
# 85    https://scistarter.com/project/205-Snow-Tweets...         205
# 92    https://scistarter.com/project/215-Lakes-of-Mi...         215
# 1125  https://scistarter.com/project/16719-Sound-Aro...       16719

# %%
# Projects that were recommended
# 585, 586, 587, 588, 589
projects[projects['project_id'].isin(project_ids.iloc[[585, 586, 587, 588, 589]].values.flatten())]
# Out:
#     UN_regions country                                        description  \
# 971         []    None  The American Woodcock Singing-Ground Survey, c...
# 972         []          The climatology of tropical cyclones is limite...
# 975         []    None  Adopt a Pixel is a citizen science program tha...
# 977         []    None  Monitor Change is a simple and elegant visual ...
# 978         []          Insect emergence is a fundamental process in s...
#
#     error                   guid        origin  \
# 971   NaN  wilsoncenter:182-None  wilsoncenter
# 972   NaN    wilsoncenter:26-202    scistarter
# 975   NaN  wilsoncenter:186-None  wilsoncenter
# 977   NaN  wilsoncenter:191-None  wilsoncenter
# 978   NaN  wilsoncenter:193-None  wilsoncenter
#
#                                                regions  \
# 971  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 972                                                 []
# 975  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 977  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 978  [{'geometry': {'type': 'MultiPolygon', 'coordi...
#
#                                                   tags  \
# 971  [american woodcock, annual survey, atlantic fl...
# 972  [climate, clouds, cyclone, hurricane, satellit...
# 975  [ground-based landscape data, Ground-based lan...
# 977  [android app, Android app, iphone app, iPhone ...
# 978  [black flies, grand canyon, insect monitoring,...
#
#                                        title  \
# 971  American Woodcock Singing-ground Survey
# 972                           Cyclone Center
# 975                            Adopt a Pixel
# 977                           Monitor Change
# 978        Citizen Science Insect Monitoring
#
#                                                 topics  \
# 971                                                 []
# 972  [Ocean, Water, Marine & Terrestrial, Geology &...
# 975                                                 []
# 977                                                 []
# 978                                                 []
#
#                                                    url  project_id
# 971  https://scistarter.com/project/1689-American-W...        1689
# 972  https://scistarter.com/project/1690-Cyclone-Ce...        1690
# 975  https://scistarter.com/project/1693-Adopt-a-Pi...        1693
# 977  https://scistarter.com/project/1695-Monitor-Ch...        1695
# 978  https://scistarter.com/project/1696-Citizen-Sc...        1696
