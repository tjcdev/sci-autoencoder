# %%
import pandas as pd
import json
import numpy as np

# %%
# Read results
results = pd.read_json('../../data/experiment-results/autoencoders/train_autoencoder_32_cdae_tfidf_description.json', lines=True)

# %%
losses = results.iloc[0]['loss']
val_losses = results.iloc[0]['val_loss']

# %%
losses
# Out:
# [1.205806355937954,
#  0.697573297429512,
#  0.569181964510963,
#  0.5157633801627021,
#  0.486427764586412,
#  0.46882734805415305,
#  0.44994109587498105,
#  0.42626413265584806,
#  0.396633052621196,
#  0.36232615315197503,
#  0.32588013313321,
#  0.289616166777577,
#  0.255014708901084,
#  0.22513711195407102,
#  0.197065551028783,
#  0.17498531250121702,
#  0.156937347235017,
#  0.14151020170095602,
#  0.12909319160461,
#  0.118819692322604,
#  0.110493405891479,
#  0.103607770558635,
#  0.098041644350427,
#  0.093251337014446,
#  0.089202630290707,
#  0.086067404810289,
#  0.082860687542575,
#  0.080070353142922,
#  0.077717871328846,
#  0.075950994226822,
#  0.07409421142821701,
#  0.07279323040275801,
#  0.07117319027955,
#  0.06996413843181301,
#  0.068718467724918,
#  0.067407385131328,
#  0.066514625203134,
#  0.065616087154845,
#  0.06446329159931101,
#  0.063585463989813,
#  0.06270972046649201,
#  0.061955592619032,
#  0.061217140851311004,
#  0.060506865341480004,
# ...

# %%
val_losses
# Out:
# [0.8096709918308921,
#  0.6001559908573441,
#  0.5336065767528291,
#  0.49569392808667406,
#  0.47635855270432403,
#  0.459819361046477,
#  0.43948792786031304,
#  0.413945182845309,
#  0.38347566836363706,
#  0.349571713826039,
#  0.31369632128235303,
#  0.278991399319855,
#  0.246986428340831,
#  0.218270199073778,
#  0.19286290707288,
#  0.17223387623166703,
#  0.154824891290464,
#  0.14026082729126102,
#  0.128027466418859,
#  0.11854643015177901,
#  0.11063188298807201,
#  0.104104495965517,
#  0.098371965485019,
#  0.093534211856085,
#  0.089603336228357,
#  0.08646648820046701,
#  0.083102757436829,
#  0.080624171382897,
#  0.078326992586359,
#  0.07636235148965001,
#  0.074621877105502,
#  0.07315039348143701,
#  0.071564100734837,
#  0.07038131720953,
#  0.06894746912526001,
#  0.06777468099669101,
#  0.066945592788132,
#  0.065796028067181,
#  0.064868666908957,
#  0.06394115184153701,
#  0.063023764926653,
#  0.06227572950033,
#  0.06156289264872301,
#  0.060697406686686,
# ...
