# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lowest_val_loss = 1
autoencoder_name = 'train_autoencoder_128_deep3_new_users_projects_0.8'
results = pd.read_json('../../data/experiment-results/autoencoders/%s.json' % (autoencoder_name), lines=True)
losses = results.iloc[0]['loss']
val_losses = results.iloc[0]['val_loss']
epochs = np.arange(1, len(losses)+1)
if min(val_losses) < lowest_val_loss:
    print('---------')
    print(min(val_losses))
    lowest_val_loss = min(val_losses)
# Out:
# ---------
# 0.05318691122323901

# %%
# Visualize loss history
plt.plot(epochs, losses, 'r--')
plt.plot(epochs, val_losses, 'b-')
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
thisplot = plt.gcf()
thisplot.savefig('../../data/experiment-results/autoencoders/graphs/%s.pdf' % (autoencoder_name))
plt.show();

# %%
# Read results
lowest_val_loss = 1
for embed_size in ['32', '64', '128']:
    for drop_prob in ['0.1', '0.5', '0.65', '0.8']:
        autoencoder_name = 'train_autoencoder_%s__new_users_projects_%s' % (embed_size, drop_prob)
        results = pd.read_json('../../data/experiment-results/autoencoders/%s.json' % (autoencoder_name), lines=True)
        losses = results.iloc[0]['loss']
        val_losses = results.iloc[0]['val_loss']
        epochs = np.arange(1, len(losses)+1)
        if min(val_losses) < lowest_val_loss:
            print('---------')
            print(embed_size)
            print(drop_prob)
            print(min(val_losses))
            lowest_val_loss = min(val_losses)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-29d21586ccc3> in <module>
#       4     for drop_prob in ['0.1', '0.5', '0.65', '0.8']:
#       5         autoencoder_name = 'train_autoencoder_%s__new_users_projects_%s' % (embed_size, drop_prob)
# ----> 6         results = pd.read_json('../../data/experiment-results/autoencoders/%s.json' % (autoencoder_name), lines=True)
#       7         losses = results.iloc[0]['loss']
#       8         val_losses = results.iloc[0]['val_loss']
#
# ~/miniconda3/envs/cdea/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~/miniconda3/envs/cdea/lib/python3.6/site-packages/pandas/io/json/json.py in read(self)
#     532             data = to_str(self.data)
#     533             obj = self._get_object_parser(
# --> 534                 self._combine_lines(data.split('\n'))
#     535             )
#     536         else:
#
# ~/miniconda3/envs/cdea/lib/python3.6/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     554         obj = None
#     555         if typ == 'frame':
# --> 556             obj = FrameParser(json, **kwargs).parse()
#     557
#     558         if typ == 'series' or obj is None:
#
# ~/miniconda3/envs/cdea/lib/python3.6/site-packages/pandas/io/json/json.py in parse(self)
#     650
#     651         else:
# --> 652             self._parse_no_numpy()
#     653
#     654         if self.obj is None:
#
# ~/miniconda3/envs/cdea/lib/python3.6/site-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     869         if orient == "columns":
#     870             self.obj = DataFrame(
# --> 871                 loads(json, precise_float=self.precise_float), dtype=None)
#     872         elif orient == "split":
#     873             decoded = {str(k): v for k, v in compat.iteritems(
#
# ValueError: Expected object or value

# %%
# Visualize loss history
plt.plot(epochs, losses, 'r--')
plt.plot(epochs, val_losses, 'b-')
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
thisplot = plt.gcf()
thisplot.savefig('../../data/experiment-results/autoencoders/graphs/%s.pdf' % (autoencoder_name))
plt.show();
